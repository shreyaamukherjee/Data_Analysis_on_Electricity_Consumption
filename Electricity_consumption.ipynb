# %% [markdown]
# # Importing libraries and package

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #   Exploration Data Analysis (EDA) and Data Cleaning

# %%
data=pd.read_csv("D:\Consumer details of Liluah Sub-Stn.csv", dtype=str )

# %%
data.head()
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
# 2                   JAMTALA WEST SANTINAGAR HOWRAH     711227  3132600
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH     711227  3132600
# 4                  WEST SANTINAGAR PRANTICK HOWRAH     711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO  ... LOCKED_OSD PREVIOUS_OSD  \
# 0  3132000   3100000        R   20211231  ...          0       (null)
# ...

# %%
data.tail()
# Out:
#              CON_ID     INST_NO                   NAME  \
# 33953  000103265266  0019574409        REKHA  KUSHWAHA
# 33954  000103172793  0019573839          SUDIP  SARKAR
# 33955  000103233168  0019505334    ASGANI  DEVI PASUAN
# 33956  000103227912  0019502220      DIPANKAR  ACHARYA
# 33957  000102955863  0019494365  BAIKUNTH KUMAR  SINGH
#
#                                                  ADDRESS PIN_CODE CCC_CODE  \
# 33953    C/O-ASHOK KR. KUSHWAHA,ANANDANAGAR,LILUAH,HO...   711227  3132600
# 33954    WEST ANANDANAGAR     LOKNATH MANDIR,SAPUIPAR...   711227  3132600
# 33955    WEST SANTINAGAR     ANANDANAGARNISCHINDA  HO...   711227  3132600
# 33956            ANANDANAGAR,NISCHINDA     BALLY,HOOWRAH   711227  3132600
# 33957    EAST ANANDANAGAR     LOKNATH MANDIR,SAPUIPAR...   711227  3132600
#
#       DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO  ... LOCKED_OSD PREVIOUS_OSD  \
# 33953  3132000   3100000        R   20170307  ...          0       (null)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33958 entries, 0 to 33957
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CON_ID                        33958 non-null  object
#  1   INST_NO                       33958 non-null  object
#  2   NAME                          33958 non-null  object
#  3   ADDRESS                       33958 non-null  object
#  4   PIN_CODE                      33958 non-null  object
#  5   CCC_CODE                      33958 non-null  object
#  6   DIV_CODE                      33958 non-null  object
#  7   ZONE_CODE                     33958 non-null  object
#  8   CATEGORY                      33958 non-null  object
#  9   DATE_OF_CO                    33958 non-null  object
#  10  BASE_CLASS                    33958 non-null  object
#  11  TARIFF_CLASS                  33958 non-null  object
# ...

# %%
data.shape
# Out:
# (33958, 52)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Cleaning

# %%
data.drop(['MOB_NO_COLLECTED_ON_SPOT','LOCKED_OSD'],axis=1,inplace=True)

# %%
data.head()
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
# 2                   JAMTALA WEST SANTINAGAR HOWRAH     711227  3132600
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH     711227  3132600
# 4                  WEST SANTINAGAR PRANTICK HOWRAH     711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  CONN_TYPE  \
# 0  3132000   3100000        R   20211231          C        A(ST)  PERMANENT
# ...

# %%
data.drop(['SOLAR_INST_DATE','SOLAR_INST_CAP','PAN','GIS_ID','EMAIL'],axis=1,inplace=True)

# %%
data.drop(['DISCON_DT','MET_CNT','REG_MOB_NO','GOVT_STAT'],axis=1,inplace=True)

# %%
data.head()
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
# 2                   JAMTALA WEST SANTINAGAR HOWRAH     711227  3132600
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH     711227  3132600
# 4                  WEST SANTINAGAR PRANTICK HOWRAH     711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  CONN_TYPE  \
# 0  3132000   3100000        R   20211231          C        A(ST)  PERMANENT
# ...

# %%
data.isnull().sum()
# Out:
# CON_ID                          0
# INST_NO                         0
# NAME                            0
# ADDRESS                         0
# PIN_CODE                        0
# CCC_CODE                        0
# DIV_CODE                        0
# ZONE_CODE                       0
# CATEGORY                        0
# DATE_OF_CO                      0
# BASE_CLASS                      0
# TARIFF_CLASS                    0
# CONN_TYPE                       0
# CONN_STAT                       0
# NAT_OF_CONN                     0
# TYPE_OF_METER                   0
# TIME_OF_DAY                     0
# CONN_PHASE                      0
# CONN_LOAD                       0
# MRU                             0
# CR_DATE                         0
# MOVE_IN_DATE                    0
# CENSUS_CODE                     0
# CONN_BY                         0
# ACC_ID                          0
# DATE_OF_EFFECT                  0
# PR_TYPE                         0
# ...

# %%
data.drop(['PREVIOUS_OSD'],axis=1,inplace=True)

# %%
data.drop(['CENSUS_CODE','PARENT_ACCOUNT'],axis=1,inplace=True)

# %%
data.head()
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
# 2                   JAMTALA WEST SANTINAGAR HOWRAH     711227  3132600
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH     711227  3132600
# 4                  WEST SANTINAGAR PRANTICK HOWRAH     711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  CONN_TYPE  \
# 0  3132000   3100000        R   20211231          C        A(ST)  PERMANENT
# ...

# %%
data['CASH_SEC_DEP']=data['CASH_SEC_DEP'].astype(float)
data['TOTAL_OSD']=data['TOTAL_OSD'].astype(float)
data['OUTSTANDING']=data['OUTSTANDING'].astype(float)
data['CONN_LOAD']=data['CONN_LOAD'].astype(float)
data.head(2)
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  CONN_TYPE  \
# 0  3132000   3100000        R   20211231          C        A(ST)  PERMANENT
# 1  3132000   3100000        R   20211225          D      A(DM-R)  PERMANENT
#
#   CONN_STAT   NAT_OF_CONN TYPE_OF_METER TIME_OF_DAY CONN_PHASE  CONN_LOAD  \
# 0      LIVE  GROCERY SHOP   ELECTRIONIC       WHOLE          1       1.17
# 1      LIVE           APL   ELECTRIONIC       WHOLE          1       0.47
#
#         MRU   CR_DATE MOVE_IN_DATE CONN_BY ACC_ID DATE_OF_EFFECT PR_TYPE  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33958 entries, 0 to 33957
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CON_ID                        33958 non-null  object
#  1   INST_NO                       33958 non-null  object
#  2   NAME                          33958 non-null  object
#  3   ADDRESS                       33958 non-null  object
#  4   PIN_CODE                      33958 non-null  object
#  5   CCC_CODE                      33958 non-null  object
#  6   DIV_CODE                      33958 non-null  object
#  7   ZONE_CODE                     33958 non-null  object
#  8   CATEGORY                      33958 non-null  object
#  9   DATE_OF_CO                    33958 non-null  object
#  10  BASE_CLASS                    33958 non-null  object
#  11  TARIFF_CLASS                  33958 non-null  object
# ...

# %%
data['DATE_OF_EFFECT']=pd.to_datetime(data['DATE_OF_EFFECT'],format='mixed')
data['OSD_DATE']=pd.to_datetime(data['OSD_DATE'],format='mixed')
data['MOVE_IN_DATE']=pd.to_datetime(data['MOVE_IN_DATE'],format='mixed')
data['CR_DATE']=pd.to_datetime(data['CR_DATE'],format='mixed')
data['DATE_OF_CO']=pd.to_datetime(data['DATE_OF_CO'],format='mixed')
data['READ_DT_LAST_BILL_OR_MOVE_IN']=pd.to_datetime(data['READ_DT_LAST_BILL_OR_MOVE_IN'],format='mixed')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33958 entries, 0 to 33957
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CON_ID                        33958 non-null  object
#  1   INST_NO                       33958 non-null  object
#  2   NAME                          33958 non-null  object
#  3   ADDRESS                       33958 non-null  object
#  4   PIN_CODE                      33958 non-null  object
#  5   CCC_CODE                      33958 non-null  object
#  6   DIV_CODE                      33958 non-null  object
#  7   ZONE_CODE                     33958 non-null  object
#  8   CATEGORY                      33958 non-null  object
#  9   DATE_OF_CO                    33958 non-null  datetime64[ns]
#  10  BASE_CLASS                    33958 non-null  object
#  11  TARIFF_CLASS                  33958 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# CON_ID                          0
# INST_NO                         0
# NAME                            0
# ADDRESS                         0
# PIN_CODE                        0
# CCC_CODE                        0
# DIV_CODE                        0
# ZONE_CODE                       0
# CATEGORY                        0
# DATE_OF_CO                      0
# BASE_CLASS                      0
# TARIFF_CLASS                    0
# CONN_TYPE                       0
# CONN_STAT                       0
# NAT_OF_CONN                     0
# TYPE_OF_METER                   0
# TIME_OF_DAY                     0
# CONN_PHASE                      0
# CONN_LOAD                       0
# MRU                             0
# CR_DATE                         0
# MOVE_IN_DATE                    0
# CONN_BY                         0
# ACC_ID                          0
# DATE_OF_EFFECT                  0
# PR_TYPE                         0
# METER_NO                        0
# ...

# %%
data.head(5)
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS PIN_CODE CCC_CODE  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW...   711227  3132600
# 2                   JAMTALA WEST SANTINAGAR HOWRAH     711227  3132600
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH     711227  3132600
# 4                  WEST SANTINAGAR PRANTICK HOWRAH     711227  3132600
#
#   DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  CONN_TYPE  \
# 0  3132000   3100000        R 2021-12-31          C        A(ST)  PERMANENT
# ...

# %%
data.tail()
# Out:
#              CON_ID     INST_NO                   NAME  \
# 33953  000103265266  0019574409        REKHA  KUSHWAHA
# 33954  000103172793  0019573839          SUDIP  SARKAR
# 33955  000103233168  0019505334    ASGANI  DEVI PASUAN
# 33956  000103227912  0019502220      DIPANKAR  ACHARYA
# 33957  000102955863  0019494365  BAIKUNTH KUMAR  SINGH
#
#                                                  ADDRESS PIN_CODE CCC_CODE  \
# 33953    C/O-ASHOK KR. KUSHWAHA,ANANDANAGAR,LILUAH,HO...   711227  3132600
# 33954    WEST ANANDANAGAR     LOKNATH MANDIR,SAPUIPAR...   711227  3132600
# 33955    WEST SANTINAGAR     ANANDANAGARNISCHINDA  HO...   711227  3132600
# 33956            ANANDANAGAR,NISCHINDA     BALLY,HOOWRAH   711227  3132600
# 33957    EAST ANANDANAGAR     LOKNATH MANDIR,SAPUIPAR...   711227  3132600
#
#       DIV_CODE ZONE_CODE CATEGORY DATE_OF_CO BASE_CLASS TARIFF_CLASS  \
# 33953  3132000   3100000        R 2017-03-07          D      A(DM-R)
# ...

# %%
data[(data['PIN_CODE']=='711227') & (data['CCC_CODE']=='3132600') & (data['DIV_CODE']=='3132000') & (data['ZONE_CODE']== '3100000') & (data['CATEGORY']=='R') ]
# Out:
#              CON_ID     INST_NO                           NAME  \
# 0      000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1      000105520708  0024919008                    BAPI  MAJHI
# 2      000105557154  0024934417                  SAHADEB  KHAN
# 3      000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4      000106142544  0026273400              DEBOBRATA  MONDAL
# ...             ...         ...                            ...
# 33953  000103265266  0019574409                REKHA  KUSHWAHA
# 33954  000103172793  0019573839                  SUDIP  SARKAR
# 33955  000103233168  0019505334            ASGANI  DEVI PASUAN
# 33956  000103227912  0019502220              DIPANKAR  ACHARYA
# 33957  000102955863  0019494365          BAIKUNTH KUMAR  SINGH
#
#                                                  ADDRESS PIN_CODE CCC_CODE  \
# 0                          SUBHAS ROY NISCHINDA HOWRAH     711227  3132600
# ...

# %%
data.drop(['PIN_CODE','CCC_CODE','DIV_CODE','ZONE_CODE','CATEGORY'],axis=1,inplace =True)
data.drop(['CONN_TYPE'],axis=1,inplace=True)

# %%
data.head(1)
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
#
#                            ADDRESS DATE_OF_CO BASE_CLASS TARIFF_CLASS  \
# 0    SUBHAS ROY NISCHINDA HOWRAH   2021-12-31          C        A(ST)
#
#   CONN_STAT   NAT_OF_CONN TYPE_OF_METER TIME_OF_DAY CONN_PHASE  CONN_LOAD  \
# 0      LIVE  GROCERY SHOP   ELECTRIONIC       WHOLE          1       1.17
#
#         MRU    CR_DATE MOVE_IN_DATE CONN_BY ACC_ID DATE_OF_EFFECT PR_TYPE  \
# 0  5KI35MMR 2022-01-05   2021-12-31     CCC     SL     2023-11-30     036
#
#     METER_NO DTR_NUMBER PRICE_CLASS  OUTSTANDING OSB_GROUP FEEDER_CODE  \
# 0  LG0089803      5K02S    PC-1PALL          0.0       SBM        0421
#
#   READ_DT_LAST_BILL_OR_MOVE_IN  CASH_SEC_DEP  TOTAL_OSD   ZLATITUDE  \
# 0                   2023-11-29       3143.65        0.0  22.6506574
#
#    ZLONGITUDE   OSD_DATE
# 0  88.3329785 2023-11-30

# %%
data.shape
# Out:
# (33958, 32)

# %%
data[data['CONN_STAT']=='LIVE'].shape
# Out:
# (31869, 32)

# %%
data[data['TYPE_OF_METER']=='ELECTRIONIC'].shape
# Out:
# (32786, 32)

# %%
data[data['CONN_PHASE']=='1'].shape
# Out:
# (32893, 32)

# %%
data[data['TIME_OF_DAY']=='WHOLE'].shape
# Out:
# (33243, 32)

# %%
data[data['CONN_BY']=='CCC'].shape
# Out:
# (33780, 32)

# %%
data[data['OSB_GROUP']=='SBM'].shape
# Out:
# (33686, 32)

# %%
data['month of read date']=data['READ_DT_LAST_BILL_OR_MOVE_IN'].dt.month

# %%
data.head(5)
# Out:
#          CON_ID     INST_NO                           NAME  \
# 0  000105527504  0024859939  M/S PREMANGSHU  KR ROY AND CO
# 1  000105520708  0024919008                    BAPI  MAJHI
# 2  000105557154  0024934417                  SAHADEB  KHAN
# 3  000105555680  0024935160        BISWAJIT  BHATTACHARJEE
# 4  000106142544  0026273400              DEBOBRATA  MONDAL
#
#                                              ADDRESS DATE_OF_CO BASE_CLASS  \
# 0                      SUBHAS ROY NISCHINDA HOWRAH   2021-12-31          C
# 1    WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOW... 2021-12-25          D
# 2                   JAMTALA WEST SANTINAGAR HOWRAH   2022-01-27          D
# 3                    PRANTIK 2 BALLY HOWRAH HOWRAH   2022-01-27          D
# 4                  WEST SANTINAGAR PRANTICK HOWRAH   2023-05-13          D
#
#   TARIFF_CLASS CONN_STAT   NAT_OF_CONN TYPE_OF_METER TIME_OF_DAY CONN_PHASE  \
# 0        A(ST)      LIVE  GROCERY SHOP   ELECTRIONIC       WHOLE          1
# ...

# %%
for col in data.describe(include='object').columns:
    print(col)
    print(data[col].unique())
    print('-'*50)
# Out:
# CON_ID
# ['000105527504' '000105520708' '000105557154' ... '000103233168'
#  '000103227912' '000102955863']
# --------------------------------------------------
# INST_NO
# ['0024859939' '0024919008' '0024934417' ... '0019505334' '0019502220'
#  '0019494365']
# --------------------------------------------------
# NAME
# ['M/S PREMANGSHU  KR ROY AND CO' 'BAPI  MAJHI' 'SAHADEB  KHAN' ...
#  'ASGANI  DEVI PASUAN' 'DIPANKAR  ACHARYA' 'BAIKUNTH KUMAR  SINGH']
# --------------------------------------------------
# ADDRESS
# ['  SUBHAS ROY NISCHINDA HOWRAH  '
#  '  WEST SANTINAGR, JAMTALA P.O.-ANANDANAGAR HOWRAH  '
#  '  JAMTALA WEST SANTINAGAR HOWRAH  ' ...
#  '  WEST ANANDANAGAR     LOKNATH MANDIR,SAPUIPARANISCHINDA HOWRAH'
#  '  WEST SANTINAGAR     ANANDANAGARNISCHINDA  HOWRAH'
#  '  ANANDANAGAR,NISCHINDA     BALLY,HOOWRAH']
# --------------------------------------------------
# BASE_CLASS
# ['C' 'D' 'I' 'A' 'W' 'H']
# --------------------------------------------------
# TARIFF_CLASS
# ...

# %%
data['NAT_OF_CONN'].value_counts().describe()
# Out:
# count       56.000000
# mean       606.392857
# std       3514.215530
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         24.250000
# max      25481.000000
# Name: count, dtype: float64

# %%
data['NAT_OF_CONN'].value_counts()
# Out:
# NAT_OF_CONN
# OTHERS                      25481
# APL                          7093
# SMALL SHOP                    369
# BPL                           186
# BIG SHOP                      161
# DOMESTIC                      112
# GROCERY SHOP                   97
# IRON FOUNDRY                   85
# PLASTIC FACT.                  45
# Tower                          34
# DEPT. OF HOUSING               30
# WHEAT GRINDING MILL            28
# COMMERCIAL                     26
# LATHE DRILL AND GRIND.         25
# Municipality                   24
# HIGH SCHOOL                    18
# GRAM PANCHAYET                 16
# PHE                            12
# NAIL INDUSTRY                  11
# WELDING                        10
# PRIMARY SCHOOL                  8
# PWD(ELECTRICAL)                 8
# MISCELLENEOUS INDUSTRIES        8
# CHEM. IND.                      7
# RUBBER INDUSTRY                 6
# STRAW CUTTING                   5
# FABRICATION                     4
# ...

# %%
data['BASE_CLASS'].value_counts()
# Out:
# BASE_CLASS
# D    27692
# C     5500
# I      711
# H       28
# W       23
# A        4
# Name: count, dtype: int64

# %%
indexs=data[(data['TIME_OF_DAY']==' ')|(data['PRICE_CLASS']==' ')|(data['OSB_GROUP']==' ')].index
data.drop(indexs,inplace=True)
data['TIME_OF_DAY'].value_counts()
# Out:
# TIME_OF_DAY
# WHOLE    33178
# TOD          2
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,10))
sns.countplot(x='TARIFF_CLASS', data=data)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='TIME_OF_DAY',y='CONN_LOAD',data=data)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='month of read date',y='CONN_LOAD',hue='TYPE_OF_METER',data=data)
plt.show()

# %%
plt.figure(figsize=(30,10))
noc=data[['NAT_OF_CONN']].value_counts()[:5]
plt.pie(noc,autopct='%.2f',labels=noc.index)
plt.show()

# %%
con=data[['CONN_STAT']].value_counts()[:3]
plt.figure(figsize=(10,5))
plt.pie(con,labels=con.index,)
plt.show()

# %%
df=data['NAT_OF_CONN'].value_counts()
type(df)
# Out:
# pandas.core.series.Series

# %%
isinstance(df,pd. Series)
# Out:
# True

# %%
dataframe=df.to_frame(name='count')
dataframe['NAT_OF_CONN']=dataframe.index
dataframe.reset_index(drop=True,inplace=True)

dataframe=dataframe[(dataframe['count']>45) & (dataframe['count']<8000)  ]
dataframe
# Out:
#    count   NAT_OF_CONN
# 1   6999           APL
# 2    363    SMALL SHOP
# 3    185           BPL
# 4    154      BIG SHOP
# 5    112      DOMESTIC
# 6     92  GROCERY SHOP
# 7     79  IRON FOUNDRY

# %%
plt.figure(figsize=(20,10))
g=sns.barplot(x='NAT_OF_CONN',y='count',data=dataframe)

# %%
plt.figure(figsize=(10,10))
sns.relplot(x='BASE_CLASS', y='CONN_LOAD',col='TIME_OF_DAY',hue='CONN_PHASE',style='CONN_PHASE', data=data)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='BASE_CLASS',y='CASH_SEC_DEP',data=data)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='BASE_CLASS',y='TOTAL_OSD',hue='BASE_CLASS',data=data)
plt.title("Base Class Vs Outstanding Due",fontsize=45 )
plt.legend(data['BASE_CLASS'].unique())
plt.show()

# %%
data['BASE_CLASS'].value_counts(normalize=True)
# Out:
# BASE_CLASS
# D    0.822634
# C    0.156841
# I    0.018927
# H    0.000784
# W    0.000693
# A    0.000121
# Name: proportion, dtype: float64

# %%
bf=base.to_frame(name='count')
bf['Base_class']=bf.index
bf.reset_index(drop=True, inplace=True)

# %%
bf
# Out:
#    count Base_class
# 0  27295          D
# 1   5204          C
# 2    628          I
# 3     26          H
# 4     23          W
# 5      4          A
